# %%
# variable int, float, string , boolean, complex, list, tuple, dict, set, class
a=12 # var opt value # dynamically typed language """ """
print(a)
print(type(a))
# Out:
# 12
# <class 'int'>

# %%
user=input("Enter your name: ")
print("hello", user)
print(type(user))
# Out:
# hello arun
# <class 'str'>

# %%
user_num=int(input("Enter your number: "))
print("hello", user_num)
print(type(user_num))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 user_num=int(input("Enter your number: "))
#       2 print("hello", user_num)
#       3 print(type(user_num))
#
# ValueError: invalid literal for int() with base 10: 'arun'

# %%
a= 10.56  # float number
print(a)
b= 2 + 3j  # complex number
print(b)
c= True  # boolean
print(c)
d= "Hello World"  # string
print(d)
e='a'  # string
print(e)
f="""she said "hello to you  don't you know?" """  # multi-line string
print(f)
# Out:
# 10.56
# (2+3j)
# True
# Hello World
# a
# she said "hello to you  don't you know?"

# %%
a=10,2,3,4,5
print(type(a))  # tuple
# Out:
# <class 'tuple'>

# %%
a=() #tuple
b=[] #list
c={k:v} #dict
d={} # set
string = "hello world" # string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 a=() #tuple
#       2 b=[] #list
# ----> 3 c={k:v} #dict
#       4 d={} # set
#       5 string = "hello world" # string
#
# NameError: name 'k' is not defined

# %%
# opt
